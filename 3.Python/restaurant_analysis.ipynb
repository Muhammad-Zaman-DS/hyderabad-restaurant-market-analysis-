# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("restaurants_sql.csv")
df.head()
# Out:
#   Restaurant_ID                                    Google_Maps_URL  \
# 0         R0001  https://www.google.com/maps/place/Hyderabad+To...
# 1         R0002  https://www.google.com/maps/place/Hyderabad+Da...
# 2         R0003  https://www.google.com/maps/place/Ridan+House+...
# 3         R0004  https://www.google.com/maps/place/The+Sicilian...
# 4         R0005  https://www.google.com/maps/place/Hyderabad+Ha...
#
#                 Restaurant_Name  Rating  Reviews     Price_Range  \
# 0  Hyderabad Tonight restaurant     4.4      720      Rs 1–5,000
# 1              Hyderabad Darbar     4.1     1715             NaN
# 2          Ridan House of Mandi     4.7     6018             NaN
# 3                  The Sicilian     4.7     1023  Rs 1,000–5,000
# 4   Hyderabad Haveli Restaurant     3.9      811      Rs 1–6,000
#
#           Category          Address Status     Opening_Hours
# 0            Asian         C84J+W5W   Open       Closes 2 AM
# ...

# %% [markdown]
# # Explore Dataset

# %%
df.info() 

df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Restaurant_ID    119 non-null    str
#  1   Google_Maps_URL  119 non-null    str
#  2   Restaurant_Name  119 non-null    str
#  3   Rating           119 non-null    float64
#  4   Reviews          119 non-null    int64
#  5   Price_Range      88 non-null     str
#  6   Category         119 non-null    str
#  7   Address          119 non-null    str
#  8   Status           117 non-null    str
#  9   Opening_Hours    100 non-null    str
# dtypes: float64(1), int64(1), str(8)
# memory usage: 9.4 KB
#            Rating      Reviews
# count  119.000000   119.000000
# mean     4.107563   856.663866
# std      0.272515  1350.176368
# min      3.400000     5.000000
# 25%      3.900000    81.500000
# 50%      4.100000   237.000000
# 75%      4.200000   873.000000
# max      4.800000  6239.000000

# %% [markdown]
# # Null Values

# %%
df.isnull().sum()
# Out:
# Restaurant_ID       0
# Google_Maps_URL     0
# Restaurant_Name     0
# Rating              0
# Reviews             0
# Price_Range        31
# Category            0
# Address             0
# Status              2
# Opening_Hours      19
# dtype: int64

# %% [markdown]
# # Top 10 Rated Restaurants

# %%
df.sort_values("Rating", ascending=False).head(10)
# Out:
#     Restaurant_ID                                    Google_Maps_URL  \
# 16          R0017  https://www.google.com/maps/place/Thali+Nation...
# 30          R0031  https://www.google.com/maps/place/Cheezistaan+...
# 58          R0059  https://www.google.com/maps/place/The+Foods+Cl...
# 102         R0103  https://www.google.com/maps/place/Haka+Chinese...
# 2           R0003  https://www.google.com/maps/place/Ridan+House+...
# 19          R0020  https://www.google.com/maps/place/Burgerizza/d...
# 3           R0004  https://www.google.com/maps/place/The+Sicilian...
# 64          R0065  https://www.google.com/maps/place/Foodi+Dragon...
# 68          R0069  https://www.google.com/maps/place/Lazzat+Resta...
# 21          R0022  https://www.google.com/maps/place/Silver+Sands...
#
#                  Restaurant_Name  Rating  Reviews     Price_Range  \
# 16                  Thali Nation     4.8      117      Rs 1–1,000
# 30       Cheezistaan 🍕 Hyderabad     4.8      139      Rs 1–1,000
# ...

# %% [markdown]
# # Most Reviewed Restaurants

# %%
df.sort_values("Reviews", ascending=False).head(10)
# Out:
#    Restaurant_ID                                    Google_Maps_URL  \
# 66         R0067  https://www.google.com/maps/place/McDonald%27s...
# 2          R0003  https://www.google.com/maps/place/Ridan+House+...
# 9          R0010  https://www.google.com/maps/place/Brohi+Baloch...
# 37         R0038  https://www.google.com/maps/place/Breeze+Fish+...
# 45         R0046  https://www.google.com/maps/place/Al+Fajr+Food...
# 5          R0006  https://www.google.com/maps/place/Royal+Taj+Re...
# 28         R0029  https://www.google.com/maps/place/KFC+%7C+Hyde...
# 34         R0035  https://www.google.com/maps/place/Hamid+Biryan...
# 73         R0074  https://www.google.com/maps/place/Al+Fajr+Food...
# 29         R0030  https://www.google.com/maps/place/Al-Sharif+Bi...
#
#                            Restaurant_Name  Rating  Reviews     Price_Range  \
# 66                              McDonald's     4.2     6239      Rs 1–5,000
# ...

# %%
df["Popularity"] = np.where(
    df["Reviews"] >= 1000,
    "Popular",
    "Normal"
)

df.head(10)
# Out:
#   Restaurant_ID                                    Google_Maps_URL  \
# 0         R0001  https://www.google.com/maps/place/Hyderabad+To...
# 1         R0002  https://www.google.com/maps/place/Hyderabad+Da...
# 2         R0003  https://www.google.com/maps/place/Ridan+House+...
# 3         R0004  https://www.google.com/maps/place/The+Sicilian...
# 4         R0005  https://www.google.com/maps/place/Hyderabad+Ha...
# 5         R0006  https://www.google.com/maps/place/Royal+Taj+Re...
# 6         R0007  https://www.google.com/maps/place/Tikka+Jee+Ho...
# 7         R0008  https://www.google.com/maps/place/Zamzam+resta...
# 8         R0009  https://www.google.com/maps/place/Marhaba+Rest...
# 9         R0010  https://www.google.com/maps/place/Brohi+Baloch...
#
#                           Restaurant_Name  Rating  Reviews     Price_Range  \
# 0            Hyderabad Tonight restaurant     4.4      720      Rs 1–5,000
# 1                        Hyderabad Darbar     4.1     1715             NaN
# ...

# %% [markdown]
# # Restaurant Categories

# %%
category_counts = df["Category"].value_counts()

plt.figure(figsize=(8,5))
plt.bar(category_counts.index, category_counts.values)
plt.title("Number of Restaurants by Category")
plt.xlabel("Category")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Helps identify the most popular restaurant types in Hyderabad.

# %% [markdown]
# # Rating Distribution

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Rating"], bins=10)
plt.title("Distribution of Restaurant Ratings")
plt.xlabel("Rating")
plt.ylabel("Number of Restaurants")
plt.show()

# %% [markdown]
# Helps understand overall customer satisfaction.

# %% [markdown]
# # Top 10 Restaurants by Reviews

# %%
top_reviews = df.sort_values("Reviews", ascending=False).head(10)

plt.figure(figsize=(10,6))
plt.barh(top_reviews["Restaurant_Name"], top_reviews["Reviews"])
plt.title("Top 10 Restaurants by Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("Restaurant")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Identifies the most popular restaurants based on customer reviews.

# %% [markdown]
# # Average Rating by Category

# %%
avg_rating = df.groupby("Category")["Rating"].mean().sort_values(ascending=False)

plt.figure(figsize=(8,5))
plt.bar(avg_rating.index, avg_rating.values)
plt.title("Average Rating by Category")
plt.xlabel("Category")
plt.ylabel("Average Rating")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Highlights the highest-rated food categories.

# %%
df.to_csv("cleaned_restaurants_final.csv", index=False, encoding="utf-8")
